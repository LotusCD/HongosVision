# %%
import requests
import json
import time

# List of all provinces (departments) in Colombia
provinces_colombia = [
    "Amazonas", "Antioquia", "Arauca", "Atlántico", "Bolívar", "Boyacá", "Caldas",
    "Caquetá", "Casanare", "Cauca", "Cesar", "Chocó", "Córdoba", "Cundinamarca", 
    "Guainía", "Guaviare", "Huila", "La Guajira", "Magdalena", "Meta", "Nariño", 
    "Norte de Santander", "Putumayo", "Quindío", "Risaralda", "San Andrés y Providencia", 
    "Santander", "Sucre", "Tolima", "Valle del Cauca", "Vaupés", "Vichada"
]

base_url = "https://api.gbif.org/v1/occurrence/search?country=CO&kingdomKey=5&limit=300&stateProvince="

all_results = []

for province in provinces_colombia:
    print(f"Starting data fetch for {province}...")
    offset = 0

    previous_results = None

    while True:
        try:
            response = requests.get(f"{base_url}{province}&offset={offset}")
            #print("RESPONSE: ", response)
            response.raise_for_status()  # Check if the request was successful
            
            data = response.json()

            #print("####DATA####: ", data)

            # Check if 'results' key exists in the response
            if 'results' not in data:
                print(f"Error: 'results' key missing in data for {province} at offset {offset}.")
                break

            # If the results are the same as the previous fetch, break
            if previous_results == data['results']:
                print(f"Detected repeated records for {province}. Stopping fetch.")
                break

            all_results.extend(data['results'])
            print(f"Fetched {len(data['results'])} records for {province} at offset {offset}.")
            
            # Store the current results for comparison in the next iteration
            previous_results = data['results']

            # Check the endOfRecords key to determine if more records are available
            if data.get('endOfRecords', False):
                print(f"Completed data fetch for {province}.")
                break

            offset += 300

            # Adding a delay to respect rate limits
            time.sleep(20)
        
        except requests.RequestException as e:
            print(f"Error fetching data for {province} at offset {offset}: {e}. Trying next province...")
            break

# Save all results to a file
output_path = "all_data_colombia.json"
with open(output_path, "w") as f:
    json.dump(all_results, f)

print(f"Data saved to {output_path}")
# Out:
# Starting data fetch for Amazonas...
# Fetched 98 records for Amazonas at offset 0.
# Completed data fetch for Amazonas.
# Starting data fetch for Antioquia...
# Fetched 300 records for Antioquia at offset 0.
# Fetched 300 records for Antioquia at offset 300.
# Fetched 300 records for Antioquia at offset 600.
# Fetched 300 records for Antioquia at offset 900.
# Fetched 300 records for Antioquia at offset 1200.
# Fetched 300 records for Antioquia at offset 1500.
# Fetched 300 records for Antioquia at offset 1800.
# Fetched 300 records for Antioquia at offset 2100.
# Fetched 300 records for Antioquia at offset 2400.
# Fetched 300 records for Antioquia at offset 2700.
# Fetched 300 records for Antioquia at offset 3000.
# Fetched 300 records for Antioquia at offset 3300.
# Fetched 300 records for Antioquia at offset 3600.
# Fetched 300 records for Antioquia at offset 3900.
# Fetched 300 records for Antioquia at offset 4200.
# Fetched 300 records for Antioquia at offset 4500.
# Fetched 300 records for Antioquia at offset 4800.
# Fetched 300 records for Antioquia at offset 5100.
# Fetched 300 records for Antioquia at offset 5400.
# Fetched 300 records for Antioquia at offset 5700.
# Fetched 300 records for Antioquia at offset 6000.
# Fetched 300 records for Antioquia at offset 6300.
# Fetched 300 records for Antioquia at offset 6600.
# Fetched 300 records for Antioquia at offset 6900.
# Fetched 300 records for Antioquia at offset 7200.
# Fetched 300 records for Antioquia at offset 7500.
# Fetched 300 records for Antioquia at offset 7800.
# Fetched 300 records for Antioquia at offset 8100.
# Fetched 300 records for Antioquia at offset 8400.
# Fetched 300 records for Antioquia at offset 8700.
# Fetched 300 records for Antioquia at offset 9000.
# Fetched 300 records for Antioquia at offset 9300.
# Fetched 300 records for Antioquia at offset 9600.
# Fetched 300 records for Antioquia at offset 9900.
# Fetched 300 records for Antioquia at offset 10200.
# Fetched 300 records for Antioquia at offset 10500.
# Fetched 300 records for Antioquia at offset 10800.
# Fetched 300 records for Antioquia at offset 11100.
# Fetched 300 records for Antioquia at offset 11400.
# Fetched 300 records for Antioquia at offset 11700.
# Fetched 300 records for Antioquia at offset 12000.
# Fetched 300 records for Antioquia at offset 12300.
# Fetched 300 records for Antioquia at offset 12600.
# Fetched 300 records for Antioquia at offset 12900.
# Fetched 300 records for Antioquia at offset 13200.
# Fetched 300 records for Antioquia at offset 13500.
# Fetched 300 records for Antioquia at offset 13800.
# Fetched 300 records for Antioquia at offset 14100.
# Fetched 300 records for Antioquia at offset 14400.
# Fetched 300 records for Antioquia at offset 14700.
# Fetched 300 records for Antioquia at offset 15000.
# Fetched 300 records for Antioquia at offset 15300.
# Fetched 300 records for Antioquia at offset 15600.
# Fetched 300 records for Antioquia at offset 15900.
# Fetched 300 records for Antioquia at offset 16200.
# Fetched 300 records for Antioquia at offset 16500.
# Fetched 300 records for Antioquia at offset 16800.
# Fetched 300 records for Antioquia at offset 17100.
# Fetched 300 records for Antioquia at offset 17400.
# Fetched 300 records for Antioquia at offset 17700.
# Fetched 300 records for Antioquia at offset 18000.
# Fetched 300 records for Antioquia at offset 18300.
# Fetched 300 records for Antioquia at offset 18600.
# Fetched 300 records for Antioquia at offset 18900.
# Fetched 300 records for Antioquia at offset 19200.
# Fetched 300 records for Antioquia at offset 19500.
# Fetched 300 records for Antioquia at offset 19800.
# Fetched 300 records for Antioquia at offset 20100.
# Fetched 300 records for Antioquia at offset 20400.
# Fetched 300 records for Antioquia at offset 20700.
# Fetched 300 records for Antioquia at offset 21000.
# Fetched 300 records for Antioquia at offset 21300.
# Fetched 300 records for Antioquia at offset 21600.
# Fetched 300 records for Antioquia at offset 21900.
# Fetched 300 records for Antioquia at offset 22200.
# Fetched 300 records for Antioquia at offset 22500.
# Fetched 300 records for Antioquia at offset 22800.
# Fetched 300 records for Antioquia at offset 23100.
# Fetched 300 records for Antioquia at offset 23400.
# Fetched 300 records for Antioquia at offset 23700.
# Fetched 300 records for Antioquia at offset 24000.
# Fetched 300 records for Antioquia at offset 24300.
# Fetched 300 records for Antioquia at offset 24600.
# Fetched 300 records for Antioquia at offset 24900.
# Fetched 300 records for Antioquia at offset 25200.
# Fetched 300 records for Antioquia at offset 25500.
# Fetched 300 records for Antioquia at offset 25800.
# Fetched 300 records for Antioquia at offset 26100.
# Fetched 300 records for Antioquia at offset 26400.
# Fetched 300 records for Antioquia at offset 26700.
# Fetched 300 records for Antioquia at offset 27000.
# Fetched 300 records for Antioquia at offset 27300.
# Fetched 300 records for Antioquia at offset 27600.
# Fetched 300 records for Antioquia at offset 27900.
# Fetched 300 records for Antioquia at offset 28200.
# Fetched 300 records for Antioquia at offset 28500.
# Fetched 300 records for Antioquia at offset 28800.
# Fetched 300 records for Antioquia at offset 29100.
# Fetched 300 records for Antioquia at offset 29400.
# Fetched 300 records for Antioquia at offset 29700.
# Fetched 300 records for Antioquia at offset 30000.
# Fetched 300 records for Antioquia at offset 30300.
# Fetched 300 records for Antioquia at offset 30600.
# Fetched 300 records for Antioquia at offset 30900.
# Fetched 300 records for Antioquia at offset 31200.
# Fetched 300 records for Antioquia at offset 31500.
# Fetched 7 records for Antioquia at offset 31800.
# Completed data fetch for Antioquia.
# Starting data fetch for Arauca...
# Fetched 300 records for Arauca at offset 0.
# Fetched 300 records for Arauca at offset 300.
# Fetched 300 records for Arauca at offset 600.
# Fetched 112 records for Arauca at offset 900.
# Completed data fetch for Arauca.
# Starting data fetch for Atlántico...
# Fetched 4 records for Atlántico at offset 0.
# Completed data fetch for Atlántico.
# Starting data fetch for Bolívar...
# Fetched 300 records for Bolívar at offset 0.
# Fetched 300 records for Bolívar at offset 300.
# Fetched 300 records for Bolívar at offset 600.
# Fetched 300 records for Bolívar at offset 900.
# Fetched 300 records for Bolívar at offset 1200.
# Fetched 300 records for Bolívar at offset 1500.
# Fetched 300 records for Bolívar at offset 1800.
# Fetched 300 records for Bolívar at offset 2100.
# Fetched 300 records for Bolívar at offset 2400.
# Fetched 300 records for Bolívar at offset 2700.
# Fetched 300 records for Bolívar at offset 3000.
# Fetched 300 records for Bolívar at offset 3300.
# Fetched 300 records for Bolívar at offset 3600.
# Fetched 300 records for Bolívar at offset 3900.
# Fetched 300 records for Bolívar at offset 4200.
# Fetched 300 records for Bolívar at offset 4500.
# Fetched 300 records for Bolívar at offset 4800.
# Fetched 300 records for Bolívar at offset 5100.
# Fetched 300 records for Bolívar at offset 5400.
# Fetched 300 records for Bolívar at offset 5700.
# Fetched 300 records for Bolívar at offset 6000.
# Fetched 300 records for Bolívar at offset 6300.
# Fetched 300 records for Bolívar at offset 6600.
# Fetched 300 records for Bolívar at offset 6900.
# Fetched 300 records for Bolívar at offset 7200.
# Fetched 300 records for Bolívar at offset 7500.
# Fetched 300 records for Bolívar at offset 7800.
# Fetched 300 records for Bolívar at offset 8100.
# Fetched 300 records for Bolívar at offset 8400.
# Fetched 300 records for Bolívar at offset 8700.
# Fetched 300 records for Bolívar at offset 9000.
# Error fetching data for Bolívar at offset 9300: HTTPSConnectionPool(host='api.gbif.org', port=443): Read timed out. (read timeout=None). Trying next province...
# Starting data fetch for Boyacá...
# Fetched 300 records for Boyacá at offset 0.
# Fetched 300 records for Boyacá at offset 300.
# Fetched 300 records for Boyacá at offset 600.
# Fetched 300 records for Boyacá at offset 900.
# Fetched 300 records for Boyacá at offset 1200.
# Fetched 300 records for Boyacá at offset 1500.
# Fetched 300 records for Boyacá at offset 1800.
# Fetched 300 records for Boyacá at offset 2100.
# Fetched 300 records for Boyacá at offset 2400.
# Fetched 300 records for Boyacá at offset 2700.
# Fetched 300 records for Boyacá at offset 3000.
# Fetched 300 records for Boyacá at offset 3300.
# Fetched 300 records for Boyacá at offset 3600.
# Fetched 248 records for Boyacá at offset 3900.
# Completed data fetch for Boyacá.
# Starting data fetch for Caldas...
# Fetched 300 records for Caldas at offset 0.
# Fetched 300 records for Caldas at offset 300.
# Fetched 300 records for Caldas at offset 600.
# Fetched 300 records for Caldas at offset 900.
# Fetched 103 records for Caldas at offset 1200.
# Completed data fetch for Caldas.
# Starting data fetch for Caquetá...
# Fetched 300 records for Caquetá at offset 0.
# Fetched 300 records for Caquetá at offset 300.
# Fetched 289 records for Caquetá at offset 600.
# Completed data fetch for Caquetá.
# Starting data fetch for Casanare...
# Fetched 300 records for Casanare at offset 0.
# Fetched 300 records for Casanare at offset 300.
# Fetched 300 records for Casanare at offset 600.
# Fetched 300 records for Casanare at offset 900.
# Fetched 300 records for Casanare at offset 1200.
# Fetched 300 records for Casanare at offset 1500.
# Fetched 300 records for Casanare at offset 1800.
# Fetched 282 records for Casanare at offset 2100.
# Completed data fetch for Casanare.
# Starting data fetch for Cauca...
# Fetched 300 records for Cauca at offset 0.
# Fetched 300 records for Cauca at offset 300.
# Fetched 300 records for Cauca at offset 600.
# Fetched 300 records for Cauca at offset 900.
# Fetched 280 records for Cauca at offset 1200.
# Completed data fetch for Cauca.
# Starting data fetch for Cesar...
# Fetched 300 records for Cesar at offset 0.
# Fetched 300 records for Cesar at offset 300.
# Fetched 7 records for Cesar at offset 600.
# Completed data fetch for Cesar.
# Starting data fetch for Chocó...
# Fetched 300 records for Chocó at offset 0.
# Fetched 44 records for Chocó at offset 300.
# Completed data fetch for Chocó.
# Starting data fetch for Córdoba...
# Fetched 300 records for Córdoba at offset 0.
# Fetched 300 records for Córdoba at offset 300.
# Fetched 300 records for Córdoba at offset 600.
# Fetched 300 records for Córdoba at offset 900.
# Fetched 300 records for Córdoba at offset 1200.
# Fetched 300 records for Córdoba at offset 1500.
# Fetched 300 records for Córdoba at offset 1800.
# Fetched 300 records for Córdoba at offset 2100.
# Fetched 300 records for Córdoba at offset 2400.
# Fetched 300 records for Córdoba at offset 2700.
# Fetched 300 records for Córdoba at offset 3000.
# Fetched 300 records for Córdoba at offset 3300.
# Fetched 300 records for Córdoba at offset 3600.
# Fetched 300 records for Córdoba at offset 3900.
# Fetched 300 records for Córdoba at offset 4200.
# Fetched 300 records for Córdoba at offset 4500.
# Fetched 300 records for Córdoba at offset 4800.
# Fetched 300 records for Córdoba at offset 5100.
# Fetched 300 records for Córdoba at offset 5400.
# Fetched 300 records for Córdoba at offset 5700.
# Fetched 300 records for Córdoba at offset 6000.
# Fetched 300 records for Córdoba at offset 6300.
# Fetched 300 records for Córdoba at offset 6600.
# Fetched 300 records for Córdoba at offset 6900.
# Fetched 300 records for Córdoba at offset 7200.
# Fetched 300 records for Córdoba at offset 7500.
# Fetched 300 records for Córdoba at offset 7800.
# Fetched 300 records for Córdoba at offset 8100.
# Fetched 300 records for Córdoba at offset 8400.
# Fetched 300 records for Córdoba at offset 8700.
# Fetched 300 records for Córdoba at offset 9000.
# Fetched 300 records for Córdoba at offset 9300.
# Fetched 17 records for Córdoba at offset 9600.
# Completed data fetch for Córdoba.
# Starting data fetch for Cundinamarca...
# Fetched 300 records for Cundinamarca at offset 0.
# Fetched 300 records for Cundinamarca at offset 300.
# Fetched 300 records for Cundinamarca at offset 600.
# Fetched 300 records for Cundinamarca at offset 900.
# Fetched 300 records for Cundinamarca at offset 1200.
# Fetched 300 records for Cundinamarca at offset 1500.
# Fetched 300 records for Cundinamarca at offset 1800.
# Fetched 300 records for Cundinamarca at offset 2100.
# Fetched 300 records for Cundinamarca at offset 2400.
# Fetched 300 records for Cundinamarca at offset 2700.
# Fetched 300 records for Cundinamarca at offset 3000.
# Fetched 300 records for Cundinamarca at offset 3300.
# Fetched 300 records for Cundinamarca at offset 3600.
# Fetched 300 records for Cundinamarca at offset 3900.
# Fetched 300 records for Cundinamarca at offset 4200.
# Fetched 300 records for Cundinamarca at offset 4500.
# Fetched 300 records for Cundinamarca at offset 4800.
# Fetched 300 records for Cundinamarca at offset 5100.
# Fetched 300 records for Cundinamarca at offset 5400.
# Fetched 300 records for Cundinamarca at offset 5700.
# Fetched 300 records for Cundinamarca at offset 6000.
# Fetched 300 records for Cundinamarca at offset 6300.
# Fetched 300 records for Cundinamarca at offset 6600.
# Fetched 300 records for Cundinamarca at offset 6900.
# Fetched 300 records for Cundinamarca at offset 7200.
# Fetched 300 records for Cundinamarca at offset 7500.
# Fetched 300 records for Cundinamarca at offset 7800.
# Fetched 300 records for Cundinamarca at offset 8100.
# Fetched 300 records for Cundinamarca at offset 8400.
# Fetched 300 records for Cundinamarca at offset 8700.
# Fetched 300 records for Cundinamarca at offset 9000.
# Fetched 300 records for Cundinamarca at offset 9300.
# Fetched 300 records for Cundinamarca at offset 9600.
# Fetched 300 records for Cundinamarca at offset 9900.
# Fetched 300 records for Cundinamarca at offset 10200.
# Fetched 300 records for Cundinamarca at offset 10500.
# Fetched 300 records for Cundinamarca at offset 10800.
# Fetched 300 records for Cundinamarca at offset 11100.
# Fetched 300 records for Cundinamarca at offset 11400.
# Fetched 300 records for Cundinamarca at offset 11700.
# Fetched 300 records for Cundinamarca at offset 12000.
# Fetched 300 records for Cundinamarca at offset 12300.
# Fetched 300 records for Cundinamarca at offset 12600.
# Fetched 300 records for Cundinamarca at offset 12900.
# Fetched 300 records for Cundinamarca at offset 13200.
# Fetched 300 records for Cundinamarca at offset 13500.
# Fetched 300 records for Cundinamarca at offset 13800.
# Fetched 300 records for Cundinamarca at offset 14100.
# Fetched 300 records for Cundinamarca at offset 14400.
# Fetched 300 records for Cundinamarca at offset 14700.
# Fetched 300 records for Cundinamarca at offset 15000.
# Fetched 300 records for Cundinamarca at offset 15300.
# Fetched 300 records for Cundinamarca at offset 15600.
# Fetched 300 records for Cundinamarca at offset 15900.
# Fetched 300 records for Cundinamarca at offset 16200.
# Fetched 300 records for Cundinamarca at offset 16500.
# Fetched 300 records for Cundinamarca at offset 16800.
# Fetched 300 records for Cundinamarca at offset 17100.
# Fetched 4 records for Cundinamarca at offset 17400.
# Completed data fetch for Cundinamarca.
# Starting data fetch for Guainía...
# Fetched 126 records for Guainía at offset 0.
# Completed data fetch for Guainía.
# Starting data fetch for Guaviare...
# Fetched 63 records for Guaviare at offset 0.
# Completed data fetch for Guaviare.
# Starting data fetch for Huila...
# Fetched 300 records for Huila at offset 0.
# Fetched 300 records for Huila at offset 300.
# Fetched 65 records for Huila at offset 600.
# Completed data fetch for Huila.
# Starting data fetch for La Guajira...
# Fetched 91 records for La Guajira at offset 0.
# Completed data fetch for La Guajira.
# Starting data fetch for Magdalena...
# Fetched 300 records for Magdalena at offset 0.
# Fetched 300 records for Magdalena at offset 300.
# Fetched 300 records for Magdalena at offset 600.
# Fetched 300 records for Magdalena at offset 900.
# Fetched 300 records for Magdalena at offset 1200.
# Fetched 300 records for Magdalena at offset 1500.
# Fetched 300 records for Magdalena at offset 1800.
# Fetched 300 records for Magdalena at offset 2100.
# Fetched 300 records for Magdalena at offset 2400.
# Fetched 300 records for Magdalena at offset 2700.
# Fetched 300 records for Magdalena at offset 3000.
# Fetched 300 records for Magdalena at offset 3300.
# Fetched 300 records for Magdalena at offset 3600.
# Fetched 300 records for Magdalena at offset 3900.
# Fetched 300 records for Magdalena at offset 4200.
# Fetched 300 records for Magdalena at offset 4500.
# Fetched 300 records for Magdalena at offset 4800.
# Fetched 300 records for Magdalena at offset 5100.
# Fetched 300 records for Magdalena at offset 5400.
# Fetched 300 records for Magdalena at offset 5700.
# Fetched 300 records for Magdalena at offset 6000.
# Fetched 195 records for Magdalena at offset 6300.
# Completed data fetch for Magdalena.
# Starting data fetch for Meta...
# Fetched 300 records for Meta at offset 0.
# Fetched 300 records for Meta at offset 300.
# Fetched 300 records for Meta at offset 600.
# Fetched 300 records for Meta at offset 900.
# Fetched 300 records for Meta at offset 1200.
# Fetched 300 records for Meta at offset 1500.
# Fetched 300 records for Meta at offset 1800.
# Fetched 300 records for Meta at offset 2100.
# Fetched 300 records for Meta at offset 2400.
# Fetched 300 records for Meta at offset 2700.
# Fetched 300 records for Meta at offset 3000.
# Fetched 300 records for Meta at offset 3300.
# Fetched 300 records for Meta at offset 3600.
# Fetched 300 records for Meta at offset 3900.
# Fetched 300 records for Meta at offset 4200.
# Fetched 300 records for Meta at offset 4500.
# Fetched 300 records for Meta at offset 4800.
# Fetched 300 records for Meta at offset 5100.
# Fetched 300 records for Meta at offset 5400.
# Fetched 300 records for Meta at offset 5700.
# Fetched 300 records for Meta at offset 6000.
# Fetched 300 records for Meta at offset 6300.
# Fetched 300 records for Meta at offset 6600.
# Fetched 300 records for Meta at offset 6900.
# Fetched 300 records for Meta at offset 7200.
# Fetched 300 records for Meta at offset 7500.
# Fetched 300 records for Meta at offset 7800.
# Fetched 300 records for Meta at offset 8100.
# Fetched 300 records for Meta at offset 8400.
# Fetched 300 records for Meta at offset 8700.
# Fetched 300 records for Meta at offset 9000.
# Fetched 300 records for Meta at offset 9300.
# Fetched 300 records for Meta at offset 9600.
# Fetched 300 records for Meta at offset 9900.
# Fetched 300 records for Meta at offset 10200.
# Fetched 300 records for Meta at offset 10500.
# Fetched 247 records for Meta at offset 10800.
# Completed data fetch for Meta.
# Starting data fetch for Nariño...
# Fetched 300 records for Nariño at offset 0.
# Fetched 300 records for Nariño at offset 300.
# Fetched 300 records for Nariño at offset 600.
# Fetched 300 records for Nariño at offset 900.
# Fetched 57 records for Nariño at offset 1200.
# Completed data fetch for Nariño.
# Starting data fetch for Norte de Santander...
# Fetched 300 records for Norte de Santander at offset 0.
# Fetched 95 records for Norte de Santander at offset 300.
# Completed data fetch for Norte de Santander.
# Starting data fetch for Putumayo...
# Fetched 300 records for Putumayo at offset 0.
# Fetched 300 records for Putumayo at offset 300.
# Fetched 300 records for Putumayo at offset 600.
# Fetched 300 records for Putumayo at offset 900.
# Fetched 300 records for Putumayo at offset 1200.
# Fetched 300 records for Putumayo at offset 1500.
# Fetched 300 records for Putumayo at offset 1800.
# Fetched 300 records for Putumayo at offset 2100.
# Fetched 300 records for Putumayo at offset 2400.
# Fetched 300 records for Putumayo at offset 2700.
# Fetched 300 records for Putumayo at offset 3000.
# Fetched 300 records for Putumayo at offset 3300.
# Fetched 300 records for Putumayo at offset 3600.
# Fetched 300 records for Putumayo at offset 3900.
# Fetched 300 records for Putumayo at offset 4200.
# Fetched 300 records for Putumayo at offset 4500.
# Fetched 300 records for Putumayo at offset 4800.
# Fetched 300 records for Putumayo at offset 5100.
# Fetched 300 records for Putumayo at offset 5400.
# Fetched 300 records for Putumayo at offset 5700.
# Fetched 300 records for Putumayo at offset 6000.
# Fetched 300 records for Putumayo at offset 6300.
# Fetched 300 records for Putumayo at offset 6600.
# Fetched 300 records for Putumayo at offset 6900.
# Fetched 300 records for Putumayo at offset 7200.
# Fetched 300 records for Putumayo at offset 7500.
# Fetched 300 records for Putumayo at offset 7800.
# Fetched 300 records for Putumayo at offset 8100.
# Fetched 300 records for Putumayo at offset 8400.
# Fetched 300 records for Putumayo at offset 8700.
# Fetched 300 records for Putumayo at offset 9000.
# Fetched 300 records for Putumayo at offset 9300.
# Fetched 300 records for Putumayo at offset 9600.
# Fetched 300 records for Putumayo at offset 9900.
# Fetched 286 records for Putumayo at offset 10200.
# Completed data fetch for Putumayo.
# Starting data fetch for Quindío...
# Fetched 300 records for Quindío at offset 0.
# Fetched 156 records for Quindío at offset 300.
# Completed data fetch for Quindío.
# Starting data fetch for Risaralda...
# Fetched 300 records for Risaralda at offset 0.
# Fetched 300 records for Risaralda at offset 300.
# Fetched 300 records for Risaralda at offset 600.
# Fetched 300 records for Risaralda at offset 900.
# Fetched 300 records for Risaralda at offset 1200.
# Fetched 300 records for Risaralda at offset 1500.
# Fetched 202 records for Risaralda at offset 1800.
# Completed data fetch for Risaralda.
# Starting data fetch for San Andrés y Providencia...
# Fetched 6 records for San Andrés y Providencia at offset 0.
# Completed data fetch for San Andrés y Providencia.
# Starting data fetch for Santander...
# Fetched 300 records for Santander at offset 0.
# Fetched 300 records for Santander at offset 300.
# Fetched 300 records for Santander at offset 600.
# Fetched 300 records for Santander at offset 900.
# Fetched 300 records for Santander at offset 1200.
# Fetched 300 records for Santander at offset 1500.
# Fetched 300 records for Santander at offset 1800.
# Fetched 300 records for Santander at offset 2100.
# Fetched 300 records for Santander at offset 2400.
# Fetched 300 records for Santander at offset 2700.
# Fetched 300 records for Santander at offset 3000.
# Fetched 300 records for Santander at offset 3300.
# Fetched 300 records for Santander at offset 3600.
# Fetched 300 records for Santander at offset 3900.
# Fetched 300 records for Santander at offset 4200.
# Fetched 300 records for Santander at offset 4500.
# Fetched 300 records for Santander at offset 4800.
# Fetched 300 records for Santander at offset 5100.
# Fetched 300 records for Santander at offset 5400.
# Fetched 300 records for Santander at offset 5700.
# Fetched 300 records for Santander at offset 6000.
# Fetched 300 records for Santander at offset 6300.
# Fetched 300 records for Santander at offset 6600.
# Fetched 300 records for Santander at offset 6900.
# Fetched 300 records for Santander at offset 7200.
# Fetched 300 records for Santander at offset 7500.
# Fetched 300 records for Santander at offset 7800.
# Fetched 300 records for Santander at offset 8100.
# Fetched 300 records for Santander at offset 8400.
# Fetched 300 records for Santander at offset 8700.
# Fetched 300 records for Santander at offset 9000.
# Fetched 300 records for Santander at offset 9300.
# Fetched 300 records for Santander at offset 9600.
# Fetched 300 records for Santander at offset 9900.
# Fetched 300 records for Santander at offset 10200.
# Fetched 300 records for Santander at offset 10500.
# Fetched 300 records for Santander at offset 10800.
# Fetched 300 records for Santander at offset 11100.
# Fetched 300 records for Santander at offset 11400.
# Fetched 300 records for Santander at offset 11700.
# Fetched 300 records for Santander at offset 12000.
# Fetched 300 records for Santander at offset 12300.
# Fetched 300 records for Santander at offset 12600.
# Fetched 300 records for Santander at offset 12900.
# Fetched 300 records for Santander at offset 13200.
# Fetched 300 records for Santander at offset 13500.
# Fetched 300 records for Santander at offset 13800.
# Fetched 300 records for Santander at offset 14100.
# Fetched 300 records for Santander at offset 14400.
# Fetched 300 records for Santander at offset 14700.
# Fetched 300 records for Santander at offset 15000.
# Fetched 300 records for Santander at offset 15300.
# Fetched 300 records for Santander at offset 15600.
# Fetched 300 records for Santander at offset 15900.
# Fetched 300 records for Santander at offset 16200.
# Fetched 300 records for Santander at offset 16500.
# Fetched 300 records for Santander at offset 16800.
# Fetched 300 records for Santander at offset 17100.
# Fetched 300 records for Santander at offset 17400.
# Fetched 300 records for Santander at offset 17700.
# Fetched 300 records for Santander at offset 18000.
# Fetched 300 records for Santander at offset 18300.
# Fetched 300 records for Santander at offset 18600.
# Fetched 300 records for Santander at offset 18900.
# Fetched 300 records for Santander at offset 19200.
# Fetched 300 records for Santander at offset 19500.
# Fetched 300 records for Santander at offset 19800.
# Fetched 300 records for Santander at offset 20100.
# Fetched 300 records for Santander at offset 20400.
# Fetched 300 records for Santander at offset 20700.
# Fetched 300 records for Santander at offset 21000.
# Fetched 300 records for Santander at offset 21300.
# Fetched 300 records for Santander at offset 21600.
# Fetched 300 records for Santander at offset 21900.
# Fetched 300 records for Santander at offset 22200.
# Fetched 300 records for Santander at offset 22500.
# Fetched 300 records for Santander at offset 22800.
# Fetched 300 records for Santander at offset 23100.
# Fetched 300 records for Santander at offset 23400.
# Fetched 300 records for Santander at offset 23700.
# Fetched 300 records for Santander at offset 24000.
# Fetched 300 records for Santander at offset 24300.
# Fetched 300 records for Santander at offset 24600.
# Fetched 300 records for Santander at offset 24900.
# Fetched 300 records for Santander at offset 25200.
# Fetched 300 records for Santander at offset 25500.
# Fetched 300 records for Santander at offset 25800.
# Fetched 300 records for Santander at offset 26100.
# Fetched 300 records for Santander at offset 26400.
# Fetched 300 records for Santander at offset 26700.
# Fetched 300 records for Santander at offset 27000.
# Fetched 300 records for Santander at offset 27300.
# Fetched 300 records for Santander at offset 27600.
# Fetched 300 records for Santander at offset 27900.
# Fetched 300 records for Santander at offset 28200.
# Fetched 300 records for Santander at offset 28500.
# Fetched 300 records for Santander at offset 28800.
# Fetched 300 records for Santander at offset 29100.
# Fetched 300 records for Santander at offset 29400.
# Fetched 300 records for Santander at offset 29700.
# Fetched 300 records for Santander at offset 30000.
# Fetched 300 records for Santander at offset 30300.
# Fetched 300 records for Santander at offset 30600.
# Fetched 300 records for Santander at offset 30900.
# Fetched 300 records for Santander at offset 31200.
# Fetched 300 records for Santander at offset 31500.
# Fetched 300 records for Santander at offset 31800.
# Fetched 300 records for Santander at offset 32100.
# Fetched 300 records for Santander at offset 32400.
# Fetched 300 records for Santander at offset 32700.
# Fetched 300 records for Santander at offset 33000.
# Fetched 300 records for Santander at offset 33300.
# Fetched 300 records for Santander at offset 33600.
# Fetched 300 records for Santander at offset 33900.
# Fetched 300 records for Santander at offset 34200.
# Fetched 300 records for Santander at offset 34500.
# Fetched 300 records for Santander at offset 34800.
# Fetched 300 records for Santander at offset 35100.
# Fetched 300 records for Santander at offset 35400.
# Fetched 300 records for Santander at offset 35700.
# Fetched 300 records for Santander at offset 36000.
# Fetched 300 records for Santander at offset 36300.
# Fetched 300 records for Santander at offset 36600.
# Fetched 300 records for Santander at offset 36900.
# Fetched 300 records for Santander at offset 37200.
# Fetched 300 records for Santander at offset 37500.
# Fetched 300 records for Santander at offset 37800.
# Fetched 300 records for Santander at offset 38100.
# Fetched 300 records for Santander at offset 38400.
# Fetched 300 records for Santander at offset 38700.
# Fetched 300 records for Santander at offset 39000.
# Fetched 300 records for Santander at offset 39300.
# Fetched 300 records for Santander at offset 39600.
# Fetched 300 records for Santander at offset 39900.
# Fetched 300 records for Santander at offset 40200.
# Fetched 300 records for Santander at offset 40500.
# Fetched 300 records for Santander at offset 40800.
# Fetched 300 records for Santander at offset 41100.
# Fetched 300 records for Santander at offset 41400.
# Fetched 42 records for Santander at offset 41700.
# Completed data fetch for Santander.
# Starting data fetch for Sucre...
# Fetched 300 records for Sucre at offset 0.
# Fetched 300 records for Sucre at offset 300.
# Fetched 300 records for Sucre at offset 600.
# Fetched 300 records for Sucre at offset 900.
# Fetched 300 records for Sucre at offset 1200.
# Fetched 300 records for Sucre at offset 1500.
# Fetched 300 records for Sucre at offset 1800.
# Fetched 269 records for Sucre at offset 2100.
# Completed data fetch for Sucre.
# Starting data fetch for Tolima...
# Fetched 300 records for Tolima at offset 0.
# Fetched 300 records for Tolima at offset 300.
# Fetched 300 records for Tolima at offset 600.
# Fetched 300 records for Tolima at offset 900.
# Fetched 300 records for Tolima at offset 1200.
# Fetched 300 records for Tolima at offset 1500.
# Fetched 300 records for Tolima at offset 1800.
# Fetched 300 records for Tolima at offset 2100.
# Fetched 93 records for Tolima at offset 2400.
# Completed data fetch for Tolima.
# Starting data fetch for Valle del Cauca...
# Fetched 300 records for Valle del Cauca at offset 0.
# Fetched 300 records for Valle del Cauca at offset 300.
# Fetched 300 records for Valle del Cauca at offset 600.
# Fetched 300 records for Valle del Cauca at offset 900.
# Fetched 300 records for Valle del Cauca at offset 1200.
# Fetched 300 records for Valle del Cauca at offset 1500.
# Fetched 300 records for Valle del Cauca at offset 1800.
# Fetched 300 records for Valle del Cauca at offset 2100.
# Fetched 300 records for Valle del Cauca at offset 2400.
# Fetched 300 records for Valle del Cauca at offset 2700.
# Fetched 300 records for Valle del Cauca at offset 3000.
# Fetched 300 records for Valle del Cauca at offset 3300.
# Fetched 84 records for Valle del Cauca at offset 3600.
# Completed data fetch for Valle del Cauca.
# Starting data fetch for Vaupés...
# Fetched 45 records for Vaupés at offset 0.
# Completed data fetch for Vaupés.
# Starting data fetch for Vichada...
# Fetched 234 records for Vichada at offset 0.
# Completed data fetch for Vichada.
# Data saved to all_data_colombia.json
